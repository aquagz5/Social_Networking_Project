# %%
#running the models
# !python train.py
# Out:
# Gathering data...
# Data read.
# /accre/arch/easybuild/software/BinDist/Anaconda3/2022.05/lib/python3.9/site-packages/sklearn/utils/validation.py:623: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /accre/arch/easybuild/software/BinDist/Anaconda3/2022.05/lib/python3.9/site-packages/sklearn/utils/validation.py:623: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /accre/arch/easybuild/software/BinDist/Anaconda3/2022.05/lib/python3.9/site-packages/sklearn/utils/validation.py:623: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /accre/arch/easybuild/software/BinDist/Anaconda3/2022.05/lib/python3.9/site-packages/sklearn/utils/validation.py:623: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# torch.Size([2, 5487167])
# torch.Size([2, 1688359])
# torch.Size([2, 1266270])
# ===== Epoch 0 ======================================================================================
# Training loss: 0.7075203657150269
# Validation loss: 0.6823357343673706
# ===== Epoch 1 ======================================================================================
# Training loss: 0.682422935962677
# Validation loss: 0.6573569178581238
# ===== Epoch 2 ======================================================================================
# Training loss: 0.6572654843330383
# Validation loss: 0.6341654062271118
# ===== Epoch 3 ======================================================================================
# Training loss: 0.6340910792350769
# Validation loss: 0.6146072745323181
# ===== Epoch 4 ======================================================================================
# Training loss: 0.6147817373275757
# Validation loss: 0.6004838943481445
# ===== Epoch 5 ======================================================================================
# Training loss: 0.600326418876648
# Validation loss: 0.5914808511734009
# ===== Epoch 6 ======================================================================================
# Training loss: 0.5915834307670593
# Validation loss: 0.5875033140182495
# Training complete
#
# Evaluating performance on test set...
# Test loss: 0.5877968072891235
# Model successfully saved

# %%
# !python predict.py
# Out:
# Gathering data...
# Data read.
# /accre/arch/easybuild/software/BinDist/Anaconda3/2022.05/lib/python3.9/site-packages/sklearn/utils/validation.py:623: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /accre/arch/easybuild/software/BinDist/Anaconda3/2022.05/lib/python3.9/site-packages/sklearn/utils/validation.py:623: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# Maximum friend count in test set: 821
#
# Beginning hit ratio calculation...
# Percent complete: 1.0%
# Percent complete: 2.0%
# Percent complete: 3.0%
# Percent complete: 4.0%
# Percent complete: 5.0%
# Percent complete: 6.0%
# Percent complete: 7.0%
# Percent complete: 8.0%
# Percent complete: 9.0%
# Percent complete: 10.0%
# Percent complete: 11.0%
# Percent complete: 12.0%
# Percent complete: 13.0%
# Percent complete: 14.0%
# Percent complete: 15.0%
# Percent complete: 16.0%
# Percent complete: 17.0%
# Percent complete: 18.0%
# Percent complete: 19.0%
# Percent complete: 20.0%
# Percent complete: 21.0%
# Percent complete: 22.0%
# Percent complete: 23.0%
# Percent complete: 24.0%
# Percent complete: 25.0%
# Percent complete: 26.0%
# Percent complete: 27.0%
# Percent complete: 28.0%
# Percent complete: 29.0%
# Percent complete: 30.0%
# Percent complete: 31.0%
# Percent complete: 32.0%
# Percent complete: 33.0%
# Percent complete: 34.0%
# Percent complete: 35.0%
# Percent complete: 36.0%
# Percent complete: 37.0%
# Percent complete: 38.0%
# Percent complete: 39.0%
# Percent complete: 40.0%
# Percent complete: 41.0%
# Percent complete: 42.0%
# Percent complete: 43.0%
# Percent complete: 44.0%
# Percent complete: 45.0%
# Percent complete: 46.0%
# Percent complete: 47.0%
# Percent complete: 48.0%
# Percent complete: 49.0%
# Percent complete: 50.0%
# Percent complete: 51.0%
# Percent complete: 52.0%
# Percent complete: 53.0%
# Percent complete: 54.0%
# Percent complete: 55.0%
# Percent complete: 56.0%
# Percent complete: 57.0%
# Percent complete: 58.0%
# Percent complete: 59.0%
# Percent complete: 60.0%
# Percent complete: 61.0%
# Percent complete: 62.0%
# Percent complete: 63.0%
# Percent complete: 64.0%
# Percent complete: 65.0%
# Percent complete: 66.0%
# Percent complete: 67.0%
# Percent complete: 68.0%
# Percent complete: 69.0%
# Percent complete: 70.0%
# Percent complete: 71.0%
# Percent complete: 72.0%
# Percent complete: 73.0%
# Percent complete: 74.0%
# Percent complete: 75.0%
# Percent complete: 76.0%
# Percent complete: 77.0%
# Percent complete: 78.0%
# Percent complete: 79.0%
# Percent complete: 80.0%
# Percent complete: 81.0%
# Percent complete: 82.0%
# Percent complete: 83.0%
# Percent complete: 84.0%
# Percent complete: 85.0%
# Percent complete: 86.0%
# Percent complete: 87.0%
# Percent complete: 88.0%
# Percent complete: 89.0%
# Percent complete: 90.0%
# Percent complete: 91.0%
# Percent complete: 92.0%
# Percent complete: 93.0%
# Percent complete: 94.0%
# Percent complete: 95.0%
# Percent complete: 96.0%
# Percent complete: 97.0%
# Percent complete: 98.0%
# Percent complete: 99.0%
# Percent complete: 100.0%
# Hit ratio: 0.11713160800883468

# %%
import subprocess
def run_command(command):
    process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
    while True:
        output = process.stdout.readline()
        if not output:
            break
        print(output.strip().decode())

# %%
# !python train.py --dropout 0.2 --hidden_dim 50 --num_layers 2 --weight_decay 0 --learning_rate 0.01 --counter 1
# Out:
# Gathering data...
# Data read.
# /accre/arch/easybuild/software/BinDist/Anaconda3/2022.05/lib/python3.9/site-packages/sklearn/utils/validation.py:623: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /accre/arch/easybuild/software/BinDist/Anaconda3/2022.05/lib/python3.9/site-packages/sklearn/utils/validation.py:623: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /accre/arch/easybuild/software/BinDist/Anaconda3/2022.05/lib/python3.9/site-packages/sklearn/utils/validation.py:623: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /accre/arch/easybuild/software/BinDist/Anaconda3/2022.05/lib/python3.9/site-packages/sklearn/utils/validation.py:623: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# torch.Size([2, 5487167])
# torch.Size([2, 1688359])
# torch.Size([2, 1266270])
# dropout = 0.2, hidden_dim = 50, num_layers = 2, weight_decay = 0.0, learning_rate = 0.01, counter = 1
# ===== Epoch 0 ======================================================================================
# Training loss: 0.7342596054077148
# Validation loss: 0.7205357551574707
# ===== Epoch 1 ======================================================================================
# Training loss: 0.6989345550537109
# Validation loss: 0.6841070652008057
# ===== Epoch 2 ======================================================================================
# Training loss: 0.6722026467323303
# Validation loss: 0.6629671454429626
# ===== Epoch 3 ======================================================================================
# Training loss: 0.6565993428230286
# Validation loss: 0.645562469959259
# ===== Epoch 4 ======================================================================================
# Training loss: 0.6442478895187378
# Validation loss: 0.6284927129745483
# ===== Epoch 5 ======================================================================================
# Training loss: 0.6329027414321899
# Validation loss: 0.6120147705078125
# ===== Epoch 6 ======================================================================================
# Training loss: 0.6224024295806885
# Validation loss: 0.6019163131713867
# Training complete
#
# Evaluating performance on test set...
# Test loss: 0.6020175218582153
# Model successfully saved

# %%
# !python predict.py --dropout 0.2 --hidden_dim 50 --num_layers 2 --weight_decay 0 --learning_rate 0.01 --counter 1
# Out:
# {'dropout': 0.2, 'hidden_dim': 50, 'num_layers': 2, 'weight_decay': 0.0, 'learning_rate': 0.01, 'counter': 1}
# Gathering data...
# Data read.
# /accre/arch/easybuild/software/BinDist/Anaconda3/2022.05/lib/python3.9/site-packages/sklearn/utils/validation.py:623: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /accre/arch/easybuild/software/BinDist/Anaconda3/2022.05/lib/python3.9/site-packages/sklearn/utils/validation.py:623: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# Maximum friend count in test set: 779
#
# Beginning hit ratio calculation...
# Percent complete: 1.0%
# Percent complete: 2.0%
# Percent complete: 3.0%
# Percent complete: 4.0%
# Percent complete: 5.0%
# Percent complete: 6.0%
# Percent complete: 7.0%
# Percent complete: 8.0%
# Percent complete: 9.0%
# Percent complete: 10.0%
# Percent complete: 11.0%
# Percent complete: 12.0%
# Percent complete: 13.0%
# Percent complete: 14.0%
# Percent complete: 15.0%
# Percent complete: 16.0%
# Percent complete: 17.0%
# Percent complete: 18.0%
# Percent complete: 19.0%
# Percent complete: 20.0%
# Percent complete: 21.0%
# Percent complete: 22.0%
# Percent complete: 23.0%
# Percent complete: 24.0%
# Percent complete: 25.0%
# Percent complete: 26.0%
# Percent complete: 27.0%
# Percent complete: 28.0%
# Percent complete: 29.0%
# Percent complete: 30.0%
# Percent complete: 31.0%
# Percent complete: 32.0%
# Percent complete: 33.0%
# Percent complete: 34.0%
# Percent complete: 35.0%
# Percent complete: 36.0%
# Percent complete: 37.0%
# Percent complete: 38.0%
# Percent complete: 39.0%
# Percent complete: 40.0%
# Percent complete: 41.0%
# Percent complete: 42.0%
# Percent complete: 43.0%
# Percent complete: 44.0%
# Percent complete: 45.0%
# Percent complete: 46.0%
# Percent complete: 47.0%
# Percent complete: 48.0%
# Percent complete: 49.0%
# Percent complete: 50.0%
# Percent complete: 51.0%
# Percent complete: 52.0%
# Percent complete: 53.0%
# Percent complete: 54.0%
# Percent complete: 55.0%
# Percent complete: 56.0%
# Percent complete: 57.0%
# Percent complete: 58.0%
# Percent complete: 59.0%
# Percent complete: 60.0%
# Percent complete: 61.0%
# Percent complete: 62.0%
# Percent complete: 63.0%
# Percent complete: 64.0%
# Percent complete: 65.0%
# Percent complete: 66.0%
# Percent complete: 67.0%
# Percent complete: 68.0%
# Percent complete: 69.0%
# Percent complete: 70.0%
# Percent complete: 71.0%
# Percent complete: 72.0%
# Percent complete: 73.0%
# Percent complete: 74.0%
# Percent complete: 75.0%
# Percent complete: 76.0%
# Percent complete: 77.0%
# Percent complete: 78.0%
# Percent complete: 79.0%
# Percent complete: 80.0%
# Percent complete: 81.0%
# Percent complete: 82.0%
# Percent complete: 83.0%
# Percent complete: 84.0%
# Percent complete: 85.0%
# Percent complete: 86.0%
# Percent complete: 87.0%
# Percent complete: 88.0%
# Percent complete: 89.0%
# Percent complete: 90.0%
# Percent complete: 91.0%
# Percent complete: 92.0%
# Percent complete: 93.0%
# Percent complete: 94.0%
# Percent complete: 95.0%
# Percent complete: 96.0%
# Percent complete: 97.0%
# Percent complete: 98.0%
# Percent complete: 99.0%
# Percent complete: 100.0%
# Hit ratio: 0.16078151060281154

# %%
import os
os.listdir()
# Out:
# ['__pycache__',
#  'data_prep.py',
#  'evaluation',
#  'model.py',
#  'models',
#  'predict.py',
#  'preprocessing',
#  'train.py',
#  '04-Fine-Tune.ipynb',
#  '.ipynb_checkpoints']

# %%
import os
dropout_layer = [0.2, 0.3, 0.4]
hidden_dim = [100, 200, 300]
num_layers = [2,3,4,5]
weight_decay = [0,0.01]
learning_rate =[0.01, 0.05]

counter = 1

for dropout in dropout_layer:
    for dim in hidden_dim:
        for layers in num_layers:
            for decay in weight_decay:
                for rate in learning_rate:
                    print(f"Training Model: {counter}---------------------------------------------\n\n\n")
                    if os.path.exists(f"evaluation/GCNLinkPrediction{counter}_eval.json"):
                        print(f"Skipping {counter} as it is already complete-----------------------------\n")
                    else:
                        train_command = f"python train.py --dropout {dropout} --hidden_dim {dim} --num_layers {layers} --weight_decay {decay} --learning_rate {rate} --counter {counter}"
                        predict_command = f"python predict.py --dropout {dropout} --hidden_dim {dim} --num_layers {layers} --weight_decay {decay} --learning_rate {rate} --counter {counter}"

                        # Run train command
                        run_command(train_command)

                        # Run predict command
                        run_command(predict_command)
                    counter += 1
# Out:
# Training Model: 1---------------------------------------------
#
#
#
# Skipping 1 as it is already complete-----------------------------
#
# Training Model: 2---------------------------------------------
#
#
#
# Skipping 2 as it is already complete-----------------------------
#
# Training Model: 3---------------------------------------------
#
#
#
# Skipping 3 as it is already complete-----------------------------
#
# Training Model: 4---------------------------------------------
#
#
#
# Skipping 4 as it is already complete-----------------------------
#
# Training Model: 5---------------------------------------------
#
#
#
# Skipping 5 as it is already complete-----------------------------
#
# Training Model: 6---------------------------------------------
#
#
#
# Skipping 6 as it is already complete-----------------------------
#
# Training Model: 7---------------------------------------------
#
#
#
# Skipping 7 as it is already complete-----------------------------
#
# Training Model: 8---------------------------------------------
#
#
#
# Skipping 8 as it is already complete-----------------------------
#
# Training Model: 9---------------------------------------------
#
#
#
# Skipping 9 as it is already complete-----------------------------
#
# Training Model: 10---------------------------------------------
#
#
#
# Skipping 10 as it is already complete-----------------------------
#
# Training Model: 11---------------------------------------------
#
#
#
# Skipping 11 as it is already complete-----------------------------
#
# Training Model: 12---------------------------------------------
#
#
#
# Skipping 12 as it is already complete-----------------------------
#
# Training Model: 13---------------------------------------------
#
#
#
# Skipping 13 as it is already complete-----------------------------
#
# Training Model: 14---------------------------------------------
#
#
#
# Skipping 14 as it is already complete-----------------------------
#
# Training Model: 15---------------------------------------------
#
#
#
# Skipping 15 as it is already complete-----------------------------
#
# Training Model: 16---------------------------------------------
#
#
#
# Skipping 16 as it is already complete-----------------------------
#
# Training Model: 17---------------------------------------------
#
#
#
# Skipping 17 as it is already complete-----------------------------
#
# Training Model: 18---------------------------------------------
#
#
#
# Skipping 18 as it is already complete-----------------------------
#
# Training Model: 19---------------------------------------------
#
#
#
# Skipping 19 as it is already complete-----------------------------
#
# Training Model: 20---------------------------------------------
#
#
#
# Skipping 20 as it is already complete-----------------------------
#
# Training Model: 21---------------------------------------------
#
#
#
# Skipping 21 as it is already complete-----------------------------
#
# Training Model: 22---------------------------------------------
#
#
#
# Skipping 22 as it is already complete-----------------------------
#
# Training Model: 23---------------------------------------------
#
#
#
# Skipping 23 as it is already complete-----------------------------
#
# Training Model: 24---------------------------------------------
#
#
#
# Skipping 24 as it is already complete-----------------------------
#
# Training Model: 25---------------------------------------------
#
#
#
# Gathering data...
# Data read.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [37], in <cell line: 10>()
#      20 predict_command = f"python predict.py --dropout {dropout} --hidden_dim {dim} --num_layers {layers} --weight_decay {decay} --learning_rate {rate} --counter {counter}"
#      22 # Run train command
# ---> 23 run_command(train_command)
#      25 # Run predict command
#      26 run_command(predict_command)
#
# Input In [25], in run_command(command)
#       3 process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
#       4 while True:
# ----> 5     output = process.stdout.readline()
#       6     if not output:
#       7         break
#
# KeyboardInterrupt:
